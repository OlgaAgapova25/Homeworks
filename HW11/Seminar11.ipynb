# %%
from sympy import *
from sympy.plotting import plot

# %%
x = Symbol('x')

# %%
fx = -5*x**2 + 10*x - 150
fx
# Out:
# -5*x**2 + 10*x - 150

# %%
plot(fx)

# %%
solve(fx,x)
# Out:
# [1 - sqrt(29)*I, 1 + sqrt(29)*I]

# %%
solve(fx>0)
# Out:
# False

# %%
solve(fx<0)
# Out:
# (-oo < x) & (x < oo)

# %%
plot(diff(fx))

# %%
solve(diff(fx)<0)
# Out:
# (1 < x) & (x < oo)

# %%
solve(diff(fx)>0)
# Out:
# (-oo < x) & (x < 1)
